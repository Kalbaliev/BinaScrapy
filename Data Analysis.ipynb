# %% [markdown]
# ### Exploraty Data Analysis

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

pd.set_option('display.max_columns', None)  
pd.set_option('display.max_rows', None)  
pd.options.display.float_format = '{:.5f}'.format

# %%
data=pd.read_json('clean-data.json')

# %%
data["UPDATETIME"]=pd.to_datetime(data["UPDATETIME"])

# %%
data.head()
# Out:
#           AGENCYNAME OWNERSHIP  COUNTNEWBUILDING  COUNTTOTAL PROPERTYDOC  \
# 0         Fortuna-N   vasitəçi                33         117         var
# 1         VİP House   vasitəçi               142         264         var
# 2  New House 28 May   vasitəçi               615         840         var
# 3           NPG MMC   vasitəçi                76         112      yoxdur
# 4     Qarabağ Əmlak   vasitəçi               127         294      yoxdur
#
#   MORTGAGE      AREA  FLOOR  MAINFLOOR  ROOMNUMBERS  URGENT  VIEWS UPDATETIME  \
# 0      var 125.00000     10          9            3  yoxdur     51 2022-04-26
# 1      var 157.00000     16          6            3  yoxdur    194 2022-04-26
# 2   yoxdur  70.00000     19          4            2  yoxdur     98 2022-04-26
# 3   yoxdur  81.00000     17          4            2  yoxdur     50 2022-04-26
# 4   yoxdur 151.00000     17         11            3  yoxdur     59 2022-04-27
#
#          MAINLOCATION  LOCATIONSSIZE  LATITUTE  LONGITUDE  UNITPRICE   PRICE
# 0          Yasamal r.              2  40.39029   49.80266       1640  205000
# 1          Yasamal r.              3  40.37885   49.83051       2230  350000
# 2          Yasamal q.              3  40.39374   49.80613       1610  112500
# 3            Xətai r.              3  40.37995   49.86621       2220  180000
# 4  9-cu mikrorayon q.              2  40.42182   49.80961       1230  185000

# %%
data.describe(include="all").T
# Out:
# <ipython-input-52-2462baf01a06>:1: FutureWarning:
#
# Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#                    count unique                  top   freq      first  \
# AGENCYNAME         20320    136               yoxdur   5989        NaT
# OWNERSHIP          20320      2             vasitəçi  18625        NaT
# COUNTNEWBUILDING 20320.0    NaN                  NaN    NaN        NaT
# COUNTTOTAL       20320.0    NaN                  NaN    NaN        NaT
# PROPERTYDOC        20320      2                  var  14010        NaT
# MORTGAGE           20320      2               yoxdur  16726        NaT
# AREA             20320.0    NaN                  NaN    NaN        NaT
# FLOOR            20320.0    NaN                  NaN    NaN        NaT
# MAINFLOOR        20320.0    NaN                  NaN    NaN        NaT
# ROOMNUMBERS      20320.0    NaN                  NaN    NaN        NaT
# URGENT             20320      2               yoxdur  14051        NaT
# VIEWS            20320.0    NaN                  NaN    NaN        NaT
# UPDATETIME         20320     32  2022-04-22 00:00:00   1170 2022-03-09
# MAINLOCATION       20320     75            Nəsimi r.   3536        NaT
# LOCATIONSSIZE    20320.0    NaN                  NaN    NaN        NaT
# LATITUTE         20320.0    NaN                  NaN    NaN        NaT
# LONGITUDE        20320.0    NaN                  NaN    NaN        NaT
# UNITPRICE        20320.0    NaN                  NaN    NaN        NaT
# PRICE            20320.0    NaN                  NaN    NaN        NaT
#
#                        last         mean          std         min  \
# AGENCYNAME              NaT          NaN          NaN         NaN
# OWNERSHIP               NaT          NaN          NaN         NaN
# COUNTNEWBUILDING        NaT    214.21585    247.37111     0.00000
# COUNTTOTAL              NaT    356.25664    379.20423     0.00000
# PROPERTYDOC             NaT          NaN          NaN         NaN
# MORTGAGE                NaT          NaN          NaN         NaN
# AREA                    NaT    117.68129     59.57306    24.00000
# FLOOR                   NaT     16.36284      3.78836     1.00000
# MAINFLOOR               NaT      9.35551      4.93567     1.00000
# ROOMNUMBERS             NaT      2.83622      0.91944     1.00000
# URGENT                  NaT          NaN          NaN         NaN
# VIEWS                   NaT    313.51801    827.27839    23.00000
# UPDATETIME       2022-04-27          NaN          NaN         NaN
# MAINLOCATION            NaT          NaN          NaN         NaN
# LOCATIONSSIZE           NaT      2.57672      1.19842     1.00000
# LATITUTE                NaT     40.39458      0.02437    40.22417
# LONGITUDE               NaT     49.85553      0.05601    49.57331
# UNITPRICE               NaT   1716.55049    621.83666   306.00000
# PRICE                   NaT 208547.11668 170682.85641 27000.00000
#
#                           25%          50%          75%           max
# AGENCYNAME                NaN          NaN          NaN           NaN
# OWNERSHIP                 NaN          NaN          NaN           NaN
# COUNTNEWBUILDING      0.00000    137.00000    371.00000     967.00000
# COUNTTOTAL            0.00000    203.00000    575.00000    1337.00000
# PROPERTYDOC               NaN          NaN          NaN           NaN
# MORTGAGE                  NaN          NaN          NaN           NaN
# AREA                 80.00000    108.00000    142.00000    1600.00000
# FLOOR                16.00000     17.00000     18.00000      33.00000
# MAINFLOOR             5.00000      9.00000     13.00000      27.00000
# ROOMNUMBERS           2.00000      3.00000      3.00000      15.00000
# URGENT                    NaN          NaN          NaN           NaN
# VIEWS                98.00000    163.00000    303.00000   41314.00000
# UPDATETIME                NaN          NaN          NaN           NaN
# MAINLOCATION              NaN          NaN          NaN           NaN
# LOCATIONSSIZE         2.00000      2.00000      3.00000      12.00000
# LATITUTE             40.38164     40.39247     40.40318      40.59244
# LONGITUDE            49.81292     49.84059     49.87527      50.12459
# UNITPRICE          1390.00000   1630.00000   1950.00000   24300.00000
# PRICE            123000.00000 168000.00000 245000.00000 5000000.00000

# %%
plt.figure(figsize=(12,8))
plt.hist(data.PRICE,bins=500);

# %%
#Maximum 5 millions AZN
# and
data.PRICE.max(),data[data.PRICE>500000].shape
# Out:
# (5000000, (673, 19))

# %%
data[data.PRICE>500000].shape[0]/data.shape[0]*100 # 3 percentages values impacts data being high skewed data
# Out:
# 3.312007874015748

# %%
plt.hist(data[data.PRICE<500000].PRICE)
# Out:
# (array([ 861., 4084., 5255., 3414., 2393., 1528.,  872.,  693.,  306.,
#          190.]),
#  array([ 27000.,  74200., 121400., 168600., 215800., 263000., 310200.,
#         357400., 404600., 451800., 499000.]),
#  <BarContainer object of 10 artists>)

# %%
#This plot describes that there is gap in the centre of baku city about new buildings

fig = px.scatter_mapbox(data, lat="LATITUTE", lon="LONGITUDE", color="AGENCYNAME", size="PRICE",
                  color_continuous_scale=px.colors.cyclical.IceFire, size_max=15, zoom=11,
                  mapbox_style="carto-positron",)
fig.show()

# %%
data.head()
# Out:
#           AGENCYNAME OWNERSHIP  COUNTNEWBUILDING  COUNTTOTAL PROPERTYDOC  \
# 0         Fortuna-N   vasitəçi                33         117         var
# 1         VİP House   vasitəçi               142         264         var
# 2  New House 28 May   vasitəçi               615         840         var
# 3           NPG MMC   vasitəçi                76         112      yoxdur
# 4     Qarabağ Əmlak   vasitəçi               127         294      yoxdur
#
#   MORTGAGE      AREA  FLOOR  MAINFLOOR  ROOMNUMBERS  URGENT  VIEWS UPDATETIME  \
# 0      var 125.00000     10          9            3  yoxdur     51 2022-04-26
# 1      var 157.00000     16          6            3  yoxdur    194 2022-04-26
# 2   yoxdur  70.00000     19          4            2  yoxdur     98 2022-04-26
# 3   yoxdur  81.00000     17          4            2  yoxdur     50 2022-04-26
# 4   yoxdur 151.00000     17         11            3  yoxdur     59 2022-04-27
#
#          MAINLOCATION  LOCATIONSSIZE  LATITUTE  LONGITUDE  UNITPRICE   PRICE
# 0          Yasamal r.              2  40.39029   49.80266       1640  205000
# 1          Yasamal r.              3  40.37885   49.83051       2230  350000
# 2          Yasamal q.              3  40.39374   49.80613       1610  112500
# 3            Xətai r.              3  40.37995   49.86621       2220  180000
# 4  9-cu mikrorayon q.              2  40.42182   49.80961       1230  185000

# %% [markdown]
# ### CounTPlots

# %%
plt.figure(figsize=(22,12))
plot=sns.countplot(x="MAINLOCATION",data=data,hue_order=True,palette="rocket",order=data['MAINLOCATION'].value_counts().index)
plt.setp(plot.get_xticklabels(), rotation=90);

# %%
data.groupby(["MAINLOCATION"]).agg({"MAINLOCATION":"count","PRICE":"mean"}).sort_values(by=["PRICE"],ascending=False)
# Out:
#                        MAINLOCATION        PRICE
# MAINLOCATION
# Səbail r.                       311 445874.12540
# Mərdəkan q.                       1 350000.00000
# Xəzər r.                          7 320600.00000
# Nəsimi r.                      3536 272785.38066
# NZS q.                            7 267942.85714
# Elmlər Akademiyası m.            17 263117.64706
# Kubinka q.                       39 254646.15385
# Nardaran q.                      16 248324.37500
# Yasamal r.                     2857 240076.90025
# Nərimanov r.                   3031 231886.40647
# Xətai r.                       2618 223790.87319
# Böyükşor q.                       4 221640.00000
# Yasamal q.                      938 214674.40085
# Bayıl q.                        117 213547.10256
# Şıxov q.                          1 201500.00000
# Xutor q.                          8 191981.25000
# Sahil q.                          4 190875.00000
# 20-ci sahə q.                     1 190000.00000
# 1-ci mikrorayon q.               53 188240.56604
# Novxanı q.                        2 185326.50000
# 8-ci mikrorayon q.              309 183770.83172
# 6-cı mikrorayon q.               72 176829.16667
# Badamdar q.                     228 174003.92982
# Suraxanı q.                       2 171350.00000
# 3-cü mikrorayon q.               79 169324.03797
# 5-ci mikrorayon q.               93 165746.23656
# Binəqədi r.                     299 165507.02007
# Balaxanı q.                       1 162000.00000
# 2-ci mikrorayon q.               27 161274.07407
# Buzovna q.                        4 161250.00000
# M.Ə.Rəsulzadə q.                 16 160712.50000
# 4-cü mikrorayon q.              180 152143.35556
# İnşaatçılar m.                    1 152000.00000
# 9-cu mikrorayon q.              352 149797.15341
# Suraxanı r.                      10 144285.00000
# 8-ci kilometr q.                442 143659.52489
# Nizami r.                       866 143560.48614
# 28 May q.                         1 134000.00000
# Əhmədli q.                      851 128301.22327
# 7-ci mikrorayon q.              213 127553.83568
# Həzi Aslanov q.                 559 127138.93023
# 2-ci Alatava q.                   2 125250.00000
# Ramana q.                         1 125000.00000
# Qaradağ r.                        5 123200.00000
# Yeni Yasamal q.                1201 121476.58951
# Keşlə q.                          1 116800.00000
# Qara Qarayev m.                   1 116500.00000
# Köhnə Günəşli q.                 29 114827.58621
# Sabunçu r.                       36 109472.22222
# Biləcəri q.                      34 108797.05882
# Bakıxanov q.                    212 107373.58962
# Qaraçuxur q.                     29  96032.58621
# Digah q.                          1  96000.00000
# Lökbatan q.                      21  86166.66667
# Yeni Günəşli q.                  51  84103.92157
# Binə q.                           3  81000.00000
# Binəqədi q.                      19  80678.94737
# Mehdiabad q.                      9  80500.00000
# Xocəsən q.                        1  80000.00000
# Massiv D q.                       5  78400.00000
# Məmmədli q.                      15  74300.00000
# Massiv V q.                       5  72400.00000
# Zığ q.                            5  71560.00000
# Abşeron r.                       72  71332.91667
# Sulutəpə q.                       3  69833.00000
# Hövsan q.                        10  69020.00000
# Kürdəxanı q.                      1  66000.00000
# Ceyranbatan q.                    6  65583.33333
# Zabrat q.                         6  63333.33333
# Masazır q.                      357  62363.72269
# Saray q.                          2  61500.00000
# Hökməli q.                        1  44000.00000
# Günəşli q.                        1  39000.00000
# Çiçək q.                          1  38000.00000
# Müşfiqabad q.                     1  36000.00000

# %%
plt.figure(figsize=(22,12))
plot=sns.countplot(x="AGENCYNAME",data=data,hue_order=True,palette="rocket",order=data['AGENCYNAME'].value_counts().index)
plt.setp(plot.get_xticklabels(), rotation=90);

# %%
data.groupby(["AGENCYNAME"]).agg({"AGENCYNAME":"count","PRICE":"mean"}).sort_values(by=["PRICE"],ascending=False)
# Out:
#                                 AGENCYNAME         PRICE
# AGENCYNAME
# PAŞA Facility Management                 1 2100000.00000
# CRES                                    32  731062.50000
# The Address                             47  640560.63830
# News Service                           113  541238.93805
# AREA                                   116  467367.67241
# Star Əmlak                              16  462281.25000
# Premium Estate MMC                      61  416979.50820
# AA Legal                                 4  412500.00000
# CASPRO                                  24  411304.16667
# Darx Real Estate                         6  365316.66667
# Rent House Baku                          5  361520.00000
# Dom v Baku                              99  343893.93939
# Grand Plaza                              5  318824.00000
# Piramida                                51  317764.70588
# Fortuna-N                               33  316939.39394
# NPG MMC                                 75  308005.33333
# RaEl                                    23  306930.43478
# VİP House                              140  300351.42857
# Real Əmlak Bakı                        516  289967.05426
# Altın Əmlak Azərbaycan MMC              68  282400.00000
# TX Group                                38  281373.68421
# Baku News Service                       11  278636.36364
# Kapital                                 85  277877.64706
# Remax                                   42  276250.00000
# My House                                24  275020.83333
# Dreamland Facility Management            1  273700.00000
# Estate 511                              49  271457.14286
# Az House                               170  265642.35294
# Garant Əmlak                           436  265133.60092
# Yadigar Əmlak                           68  263427.94118
# Dom v Baku Hüseyn Cavid                 43  263411.62791
# New Europe                              72  260545.83333
# Max Pro                                 12  252750.00000
# Birlik  Əmlak                           54  252644.44444
# Avalon                                 397  252237.15365
# Dostluq Əmlak                          253  251479.84190
# Best House                             169  250204.14201
# New Life Caspian                       123  246468.29268
# Nizami City                              9  243032.33333
# EvAl Əmlak                              19  242473.68421
# Nərimanovda Evlər                       28  241642.85714
# Friend House                           157  240836.30573
# Ülvü Əmlak                              50  239540.00000
# İdeal house                             38  238921.05263
# Elmlər Əmlak                           154  238124.99351
# Real Əmlak Gənclik                     355  236649.00845
# Mydom                                  139  233676.97842
# Nərimanov Əmlak                        508  233505.51181
# Müasir Əmlak                            30  232600.00000
# İnter Əmlak                             25  231444.00000
# Baku Realtor                           135  231016.59259
# Majestic Palace                          3  229333.33333
# ProHome                                 58  225635.86207
# Sea Breeze Real Estate                   7  225055.71429
# Real Əmlak Nizami                      214  225041.58879
# Xəzər Əmlak İnvestisiya                 46  224130.43478
# Dostlar                                 34  222744.11765
# Real Əmlak Yeni Yasamal                918  222638.20479
# Emin Əmlak                              22  219681.81818
# Təbriz Əmlak                            56  218705.35714
# Yeni Mənzil                             15  217800.00000
# A Home Company                          32  217296.87500
# Royal Estate Baku                       50  213850.00000
# New Life                               227  212491.18943
# Big House                                6  211700.00000
# Rich Estate Baku                       143  211644.05594
# Asan Əmlak                              39  211282.05128
# Dost Əmlak                             144  210690.27778
# Perfect Home                             6  204000.00000
# New House 28 May                       590  203316.79492
# Real Əmlak Parlament                   155  201705.16129
# Rahat Əmlak                             80  201043.75000
# Modern Əmlak                           167  198988.02395
# Luxury Property                        177  198321.46893
# Real Əmlak Azadlıq                     107  197606.54206
# Prant                                   23  197000.00000
# Monolit Real Estate                     58  196126.72414
# Ağaoğlu Əmlak                           52  196000.00000
# Əmlak Plaza                             42  195917.85714
# New House Gənclik                      331  194237.16012
# ASFAN                                   68  192661.76471
# yoxdur                                5989  191880.59392
# Welhome                                122  189634.46721
# New Baku Real Estate Agency              8  186750.00000
# 1 Group MMC                            105  186309.52381
# Nasimi Residence                         4  183750.00000
# New House Mətbuat                      466  182230.03863
# Uğur Əmlak                             120  177895.83333
# New House Nəsimi                       403  177545.64268
# Qarabağ Əmlak                          119  175407.56303
# Nadiroğlu Əmlak                         37  174959.45946
# Qafqaz Əmlak                            50  174380.00000
# Ekskluziv Əmlak 28 may                  34  173486.76471
# Broker                                 120  173020.84167
# Evilla                                  12  171000.00000
# Əcəmi Əmlak                            323  170815.40557
# “Cavidan Company” MMC                   21  170380.95238
# Karkas Əmlak                            46  170334.78261
# Çinar Əmlak                            391  169180.90537
# Zirvə RA Əmlak                          90  169130.00000
# MS Group                                28  166875.00000
# Melissa Group                           18  165351.11111
# Grand Əmlak                             51  164412.11765
# Nur                                     81  163927.16049
# Ağ Evlər                               136  163304.41176
# New House 20 Yanvar                    200  163045.97500
# Eden Company                           144  160176.38889
# Garanti Əmlak MMC Baş ofis              40  150125.00000
# Qarayev Əmlak                          196  146760.20408
# İnci Əmlak                               6  145666.66667
# Real Əmlak Həzi Aslanov                286  145504.37063
# Caspian                                 94  144549.25532
# Hemax                                   73  144376.71233
# Garanti Əmlak                          145  142503.59310
# City House                             312  140359.42949
# Smart House                             91  136592.30769
# Gold Əmlak                              55  132587.16364
# Azər Estate                             90  131388.88889
# Ev Bakı                                134  131067.91045
# My Home                                 67  127813.77612
# Avito Estate                            20  126750.00000
# Baku House                              75  126473.33333
# Bakı RA                                 69  124456.52174
# Əhmədli Əmlak                           10  122700.00000
# Zəfər RA Əmlak                           6  120333.33333
# YeniPark                               234  119882.47863
# Elit Əmlak                              55  116809.09091
# Avant Park                               8  111902.75000
# Modern Park                             37   96810.81081
# Rehouse                                  3   94666.66667
# Yaşam                                    9   93945.00000
# Çinarlı MTK                             23   92989.43478
# Rüfət & Aynur                            1   74500.00000
# Xırdalan VV Əmlak                        2   64500.00000
# Masazır                                 60   59888.33333
# Xırdalan RA Əmlak                        2   55500.00000

# %%
# the best buildings' room numbers for sale  = 3 

# top 3 - > 3,2,4

plt.figure(figsize=(22,12))
splot=sns.countplot(x="ROOMNUMBERS",data=data,hue_order=True,palette="rocket",order=data['ROOMNUMBERS'].value_counts().index)

for p in splot.patches:
    splot.annotate(p.get_height(), (p.get_x() + p.get_width() / 2., p.get_height()), ha = 'center', va = 'center', xytext = (0, 10), textcoords = 'offset points')

# %%
# the best buildings' floor for sale  = 5 

# top 3 - > 5,4,3
plt.figure(figsize=(22,12))
splot=sns.countplot(x="MAINFLOOR",data=data,hue_order=True,palette="rocket",order=data['MAINFLOOR'].value_counts().index)

for p in splot.patches:
    splot.annotate(p.get_height(), (p.get_x() + p.get_width() / 2., p.get_height()), ha = 'center', va = 'center', xytext = (0, 10), textcoords = 'offset points')

# %%
# the best buildings' floor type for sale  = 16

# top 3 - > 16,17,18
plt.figure(figsize=(22,12))
splot=sns.countplot(x="FLOOR",data=data,hue_order=True,palette="rocket",order=data['FLOOR'].value_counts().index)

for p in splot.patches:
    splot.annotate(p.get_height(), (p.get_x() + p.get_width() / 2., p.get_height()), ha = 'center', va = 'center', xytext = (0, 10), textcoords = 'offset points')

# %%
for col in ["MORTGAGE","URGENT","PROPERTYDOC"]:
    sns.catplot(x=col, y="PRICE", kind="box", data=data)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20320 entries, 0 to 20319
# Data columns (total 19 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   AGENCYNAME        20320 non-null  object
#  1   OWNERSHIP         20320 non-null  object
#  2   COUNTNEWBUILDING  20320 non-null  int64
#  3   COUNTTOTAL        20320 non-null  int64
#  4   PROPERTYDOC       20320 non-null  object
#  5   MORTGAGE          20320 non-null  object
#  6   AREA              20320 non-null  float64
#  7   FLOOR             20320 non-null  int64
#  8   MAINFLOOR         20320 non-null  int64
#  9   ROOMNUMBERS       20320 non-null  int64
#  10  URGENT            20320 non-null  object
#  11  VIEWS             20320 non-null  int64
#  12  UPDATETIME        20320 non-null  datetime64[ns]
#  13  MAINLOCATION      20320 non-null  object
#  14  LOCATIONSSIZE     20320 non-null  int64
#  15  LATITUTE          20320 non-null  float64
#  16  LONGITUDE         20320 non-null  float64
#  17  UNITPRICE         20320 non-null  int64
#  18  PRICE             20320 non-null  int64
# dtypes: datetime64[ns](1), float64(3), int64(9), object(6)
# memory usage: 2.9+ MB

# %%
sns.pairplot(data[["COUNTNEWBUILDING","COUNTTOTAL","FLOOR","MAINFLOOR","ROOMNUMBERS","VIEWS","LOCATIONSSIZE","UNITPRICE","PRICE"]] ,palette = 'rocket')

# %%
month=pd.DataFrame()
month["month"]=data.UPDATETIME.dt.to_period('M')
sns.countplot(x='month',data=month)
# Out:
# <AxesSubplot:xlabel='month', ylabel='count'>

# %%
# For this plot , there is multicorellation countnewbuilding and counttoal , and delete countnewbuilding columns and low percentage columns additionally latitute and longitude, updatetime(time variable)

plt.figure(figsize=(22,12))
sns.heatmap(data.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
data.head()
# Out:
#           AGENCYNAME OWNERSHIP  COUNTNEWBUILDING  COUNTTOTAL PROPERTYDOC  \
# 0         Fortuna-N   vasitəçi                33         117         var
# 1         VİP House   vasitəçi               142         264         var
# 2  New House 28 May   vasitəçi               615         840         var
# 3           NPG MMC   vasitəçi                76         112      yoxdur
# 4     Qarabağ Əmlak   vasitəçi               127         294      yoxdur
#
#   MORTGAGE      AREA  FLOOR  MAINFLOOR  ROOMNUMBERS  URGENT  VIEWS UPDATETIME  \
# 0      var 125.00000     10          9            3  yoxdur     51 2022-04-26
# 1      var 157.00000     16          6            3  yoxdur    194 2022-04-26
# 2   yoxdur  70.00000     19          4            2  yoxdur     98 2022-04-26
# 3   yoxdur  81.00000     17          4            2  yoxdur     50 2022-04-26
# 4   yoxdur 151.00000     17         11            3  yoxdur     59 2022-04-27
#
#          MAINLOCATION  LOCATIONSSIZE  LATITUTE  LONGITUDE  UNITPRICE   PRICE
# 0          Yasamal r.              2  40.39029   49.80266       1640  205000
# 1          Yasamal r.              3  40.37885   49.83051       2230  350000
# 2          Yasamal q.              3  40.39374   49.80613       1610  112500
# 3            Xətai r.              3  40.37995   49.86621       2220  180000
# 4  9-cu mikrorayon q.              2  40.42182   49.80961       1230  185000

# %%
truefalsemapper={'var':1,'yoxdur':0}
ownermapper={"vasitəçi":1,"mülkiyyətçi":0}
for col in ["PROPERTYDOC","MORTGAGE","URGENT"]:
    data[col]=data[col].map(truefalsemapper)
data["OWNERSHIP"]=data["OWNERSHIP"].map(ownermapper)

# %%
data.head()
# Out:
#           AGENCYNAME  OWNERSHIP  COUNTNEWBUILDING  COUNTTOTAL  PROPERTYDOC  \
# 0         Fortuna-N           1                33         117            1
# 1         VİP House           1               142         264            1
# 2  New House 28 May           1               615         840            1
# 3           NPG MMC           1                76         112            0
# 4     Qarabağ Əmlak           1               127         294            0
#
#    MORTGAGE      AREA  FLOOR  MAINFLOOR  ROOMNUMBERS  URGENT  VIEWS  \
# 0         1 125.00000     10          9            3       0     51
# 1         1 157.00000     16          6            3       0    194
# 2         0  70.00000     19          4            2       0     98
# 3         0  81.00000     17          4            2       0     50
# 4         0 151.00000     17         11            3       0     59
#
#   UPDATETIME        MAINLOCATION  LOCATIONSSIZE  LATITUTE  LONGITUDE  \
# 0 2022-04-26          Yasamal r.              2  40.39029   49.80266
# 1 2022-04-26          Yasamal r.              3  40.37885   49.83051
# 2 2022-04-26          Yasamal q.              3  40.39374   49.80613
# 3 2022-04-26            Xətai r.              3  40.37995   49.86621
# 4 2022-04-27  9-cu mikrorayon q.              2  40.42182   49.80961
#
#    UNITPRICE   PRICE
# 0       1640  205000
# 1       2230  350000
# 2       1610  112500
# 3       2220  180000
# 4       1230  185000

# %%
data.drop(["AGENCYNAME","UPDATETIME","MAINLOCATION","LATITUTE","LONGITUDE","UNITPRICE"],axis=1,inplace=True)

# %%
data.head()
# Out:
#    OWNERSHIP  COUNTNEWBUILDING  COUNTTOTAL  PROPERTYDOC  MORTGAGE      AREA  \
# 0          1                33         117            1         1 125.00000
# 1          1               142         264            1         1 157.00000
# 2          1               615         840            1         0  70.00000
# 3          1                76         112            0         0  81.00000
# 4          1               127         294            0         0 151.00000
#
#    FLOOR  MAINFLOOR  ROOMNUMBERS  URGENT  VIEWS  LOCATIONSSIZE   PRICE
# 0     10          9            3       0     51              2  205000
# 1     16          6            3       0    194              3  350000
# 2     19          4            2       0     98              3  112500
# 3     17          4            2       0     50              3  180000
# 4     17         11            3       0     59              2  185000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20320 entries, 0 to 20319
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   OWNERSHIP         20320 non-null  int64
#  1   COUNTNEWBUILDING  20320 non-null  int64
#  2   COUNTTOTAL        20320 non-null  int64
#  3   PROPERTYDOC       20320 non-null  int64
#  4   MORTGAGE          20320 non-null  int64
#  5   AREA              20320 non-null  float64
#  6   FLOOR             20320 non-null  int64
#  7   MAINFLOOR         20320 non-null  int64
#  8   ROOMNUMBERS       20320 non-null  int64
#  9   URGENT            20320 non-null  int64
#  10  VIEWS             20320 non-null  int64
#  11  LOCATIONSSIZE     20320 non-null  int64
#  12  PRICE             20320 non-null  int64
# dtypes: float64(1), int64(12)
# memory usage: 2.0 MB

# %%
data.shape,data.isnull().sum().sum()
# Out:
# ((20320, 13), 0)

# %%
data.drop_duplicates(inplace=True)
data.shape
# Out:
# (20318, 13)

# %%
plt.figure(figsize=(15,15))
sns.heatmap(data.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
# from sklearn.preprocessing import OneHotEncoder
# import numpy as np
# encoder = OneHotEncoder(handle_unknown="ignore",sparse=False,dtype=np.uint8)
# categorical_data=pd.DataFrame(encoder.fit_transform(data.select_dtypes(include=["object"])),columns=encoder.get_feature_names_out()).reset_index().drop(["index"],axis=1)
# categorical_data.head()

# %%
numerical_data=data.select_dtypes(exclude=["object"]).reset_index().drop(["PRICE","index"],axis=1)
from sklearn.preprocessing import StandardScaler

sc=StandardScaler().fit(numerical_data)
numerical_data_scaled=pd.DataFrame(sc.transform(numerical_data),columns=numerical_data.columns)
numerical_data_scaled.head()
# Out:
#    OWNERSHIP  COUNTNEWBUILDING  COUNTTOTAL  PROPERTYDOC  MORTGAGE     AREA  \
# 0    0.30169          -0.73254    -0.63096      0.67116   2.15715  0.12284
# 1    0.30169          -0.29192    -0.24332      0.67116   2.15715  0.65999
# 2    0.30169           1.62014     1.27562      0.67116  -0.46357 -0.80037
# 3    0.30169          -0.55872    -0.64415     -1.48996  -0.46357 -0.61573
# 4    0.30169          -0.35255    -0.16420     -1.48996  -0.46357  0.55927
#
#      FLOOR  MAINFLOOR  ROOMNUMBERS   URGENT    VIEWS  LOCATIONSSIZE
# 0 -1.67952   -0.07219      0.17809 -0.66785 -0.31735       -0.48128
# 1 -0.09569   -0.68007      0.17809 -0.66785 -0.14450        0.35314
# 2  0.69623   -1.08533     -0.90953 -0.66785 -0.26054        0.35314
# 3  0.16829   -1.08533     -0.90953 -0.66785 -0.31856        0.35314
# 4  0.16829    0.33306      0.17809 -0.66785 -0.30768       -0.48128

# %%
numerical_data_scaled.shape
# Out:
# (20318, 12)

# %%
#final_data=pd.concat([numerical_data_scaled,categorical_data],axis=1)
final_data=numerical_data_scaled
# final_data=pd.concat([numerical_data_scaled,data[["OWNERSHIP","PROPERTYDOC","MORTGAGE","URGENT"]].reset_index().drop(["index"],axis=1)],axis=1)

# %%
final_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20318 entries, 0 to 20317
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   OWNERSHIP         20318 non-null  float64
#  1   COUNTNEWBUILDING  20318 non-null  float64
#  2   COUNTTOTAL        20318 non-null  float64
#  3   PROPERTYDOC       20318 non-null  float64
#  4   MORTGAGE          20318 non-null  float64
#  5   AREA              20318 non-null  float64
#  6   FLOOR             20318 non-null  float64
#  7   MAINFLOOR         20318 non-null  float64
#  8   ROOMNUMBERS       20318 non-null  float64
#  9   URGENT            20318 non-null  float64
#  10  VIEWS             20318 non-null  float64
#  11  LOCATIONSSIZE     20318 non-null  float64
# dtypes: float64(12)
# memory usage: 1.9 MB

# %%
fcols = final_data.select_dtypes('float').columns
final_data[fcols] = final_data[fcols].apply(pd.to_numeric, downcast='float')

# %%
final_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20318 entries, 0 to 20317
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   OWNERSHIP         20318 non-null  float32
#  1   COUNTNEWBUILDING  20318 non-null  float32
#  2   COUNTTOTAL        20318 non-null  float32
#  3   PROPERTYDOC       20318 non-null  float32
#  4   MORTGAGE          20318 non-null  float32
#  5   AREA              20318 non-null  float32
#  6   FLOOR             20318 non-null  float32
#  7   MAINFLOOR         20318 non-null  float32
#  8   ROOMNUMBERS       20318 non-null  float32
#  9   URGENT            20318 non-null  float32
#  10  VIEWS             20318 non-null  float32
#  11  LOCATIONSSIZE     20318 non-null  float32
# dtypes: float32(12)
# memory usage: 952.5 KB

# %%
from sklearn.model_selection import train_test_split

y=data.PRICE
X=final_data

X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.23,random_state=0)
X_train.shape,X_test.shape,y_train.shape,y_test.shape
# Out:
# ((15644, 12), (4674, 12), (15644,), (4674,))

# %%
X.shape,y.shape
# Out:
# ((20318, 12), (20318,))

# %%
from sklearn.ensemble import RandomForestRegressor
rf = RandomForestRegressor(random_state=42,n_jobs=-1)

rf_model=rf.fit(X_train,y_train)
rf_y_pred=rf_model.predict(X_test)

# %%
def difference_percentage(true_price, predicted_price):
    diff = abs(true_price - predicted_price)
    p = (diff * 100) / true_price
    return p

# %%
rf_features_importance=pd.DataFrame({
    "Features":list(rf_model.feature_importances_)
},index=X.columns).sort_values(by="Features",axis=0,ascending=True)

fig = plt.figure(figsize=(12,6))
ax = fig.add_axes([0,0,1,1])
    
ax.barh(rf_features_importance.index[-10:],rf_features_importance.Features[-10:],color="purple")

for i, v in enumerate(rf_features_importance.Features[-10:]):
    ax.text(v+0.001, i,('% 0.2f' % v)+"%")
    
plt.show()

# %%
from sklearn.metrics import r2_score,mean_squared_error,mean_absolute_error
import numpy as np
r_squared=r2_score(y_test,rf_y_pred)
adjr_squared=1 - (1-r_squared)*(len(y_test)-1)/(len(y_test)-X.shape[1]-1)
mse=mean_squared_error(y_test,rf_y_pred)
rmse=(mse)**(1/2)
rmspe = (np.sqrt(np.mean(np.square((y_test - rf_y_pred) / y_test)))) * 100
mape = np.mean(np.abs((y_test - rf_y_pred)/y))*100
print("R-Squared =",r_squared,
      "\nAdj R-Squared =",adjr_squared,
      "\nMean Squared Error =",mse,
      "\nRoot Mean Squared Error =",rmse)
# Out:
# R-Squared = 0.7663199591829606
# Adj R-Squared = 0.7657183371083405
# Mean Squared Error = 6935262294.848786
# Root Mean Squared Error = 83278.22221234544

# %%
rf_result=pd.DataFrame({"price":y_test,"price_pred":rf_y_pred})
rf_result["difference_percentage_pred"] = rf_result.apply(lambda row : difference_percentage(row['price'], row['price_pred'] ), axis=1)

# %%
rf_result[rf_result.difference_percentage_pred>=20].sort_values(by=['difference_percentage_pred'],ascending= False).shape
# Out:
# (1489, 3)

# %%
rf_result.sort_values(by=['difference_percentage_pred'],ascending=[False]).head(20)
# Out:
#         price   price_pred  difference_percentage_pred
# 9175    52000 187606.00000                   260.78077
# 2808    60000 202513.01000                   237.52168
# 19735  210000 708749.99000                   237.50000
# 10978  153000 457386.40000                   198.94536
# 7183   305000 886369.00000                   190.61279
# 6740    73000 192219.02000                   163.31373
# 7222   340200 891995.00000                   162.19724
# 3865   190000 486782.48000                   156.20131
# 2134   130000 324440.00000                   149.56923
# 12758   36000  89258.50000                   147.94028
# 12268  270000 668127.00000                   147.45444
# 12174  104888 258841.50000                   146.77895
# 1001   306000 747376.50000                   144.24069
# 8461   178000 431555.57000                   142.44695
# 9203    60000 145047.60000                   141.74600
# 2424   130000 308797.00000                   137.53615
# 20066  210000 495011.10000                   135.71957
# 6936    87000 200074.55000                   129.97075
# 4861   225000 511823.12000                   127.47694
# 18641   51500 115845.00000                   124.94175

# %%
print("{0}/{1} - Percentage of correct values :{2} %".format(len(rf_result[rf_result.difference_percentage_pred<10]),len(rf_result),int(len(rf_result[rf_result.difference_percentage_pred<10])/len(rf_result)*100)))
# Out:
# 1871/4674 - Percentage of correct values :40 %

# %%
fig, ax = plt.subplots(figsize=(10,10))
ax.scatter(y_test,rf_y_pred, color='green')
ax.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'k--', lw=3)
ax.set_xlabel('Real')
ax.set_ylabel('Predicted')
plt.show()
